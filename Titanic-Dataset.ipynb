# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("train-2.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
gf = df.drop(['Cabin'],axis=1)

# %%
gf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
av = np.mean(gf['Age'])

# %%
av
# Out:
# 29.69911764705882

# %%
gf['Age'] = gf['Age'].fillna(av)

# %%
gf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
gf.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
gf['Embarked'] = gf['Embarked'].fillna('s')

# %%
gf.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
Rich = gf[(gf['Survived']==1)& (gf['Fare']>50)]

# %%
richp=gf[gf['Fare']>50]

# %%
richp.count()
# Out:
# PassengerId    160
# Survived       160
# Pclass         160
# Name           160
# Sex            160
# Age            160
# SibSp          160
# Parch          160
# Ticket         160
# Fare           160
# Embarked       160
# dtype: int64

# %%
Rich
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 52            53         1       1
# 61            62         1       1
# ..           ...       ...     ...
# 838          839         1       3
# 849          850         1       1
# 856          857         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  29.699118
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.000000
# 61                                 Icard, Miss. Amelie  female  38.000000
# ..                                                 ...     ...        ...
# ...

# %%
gf[gf['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
Middlep=gf[(gf['Fare']>25)& (gf['Fare']<50)]

# %%
Middlep
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 11            12         1       1
# 13            14         0       3
# 16            17         0       3
# 20            21         0       2
# ..           ...       ...     ...
# 862          863         1       1
# 880          881         1       2
# 885          886         0       3
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# 20                                Fynney, Mr. Joseph J    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Middlep.count()
# Out:
# PassengerId    173
# Survived       173
# Pclass         173
# Name           173
# Sex            173
# Age            173
# SibSp          173
# Parch          173
# Ticket         173
# Fare           173
# Embarked       173
# dtype: int64

# %%
middles =  gf[(gf['Survived']==1)& (gf['Fare']>25)& (gf['Fare']<50)]

# %%
middles
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 11            12         1       1
# 23            24         1       1
# 25            26         1       3
# 43            44         1       2
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
poorp=gf[gf['Fare']<25]

# %%
poorp
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
poors= gf[(gf['Survived']==1)& (gf['Fare']<25)]

# %%
poors
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 15            16         1       2
# 17            18         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 866          867         1       2
# 869          870         1       3
# 874          875         1       2
# 875          876         1       3
#
#                                                   Name     Sex        Age  \
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.000000
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.000000
# 17                        Williams, Mr. Charles Eugene    male  29.699118
# ..                                                 ...     ...        ...
# ...

# %%
# Out of 891 people from titanic ship 342 people were survived
# And the max cost of ticket from Fare is 512$
# let us consider that the people who bought ticket for above 50$ are rich
# According to that we have 109 rich people who were survived out of 160 rich people
# The percentge of rich people who were survived is 68%
# We have 173 middle class people 73 were survived
# The percentage of middle class people who were survived is 42%
# We have 160 people who were survived out of 557 poor people
# the perecentage of poor people who survived is 28%
# That means rich people were mostly survived
